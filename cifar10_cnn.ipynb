# %%
from keras.datasets import cifar10

#loading datasets

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPool2D
from keras.utils import np_utils

# %%
# building vector from 32x32 pixels

X_train = x_train.reshape(x_train.shape[0],32,32,3)
X_test = x_test.reshape(x_test.shape[0],32,32,3)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalization

X_train /=255
X_test /=255

# %%
n_classes = 10
Y_train = np_utils.to_categorical(y_train, n_classes)
Y_test = np_utils.to_categorical(y_test, n_classes)

# %%
model = Sequential()

#convolution layer
model.add(Conv2D(50, kernel_size=(3,3),strides=(1,1),padding='same',activation='relu', input_shape=(32,32,3)))

#convolution layer
model.add(Conv2D(75, kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(125, kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))



model.add(Flatten())

# hidden layer
model.add(Dense(500,activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(250,activation='relu'))
model.add(Dropout(0.3))

# output layer
model.add(Dense(10,activation='softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 50)        1400
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 75)        33825
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 75)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 75)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 125)       84500
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 125)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 125)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 8000)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 500)               4000500
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 250)               125250
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                2510
# =================================================================
# Total params: 4,247,985
# Trainable params: 4,247,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/10
# 391/391 [==============================] - 8s 20ms/step - loss: 1.5941 - accuracy: 0.4144 - val_loss: 1.1571 - val_accuracy: 0.5929
# Epoch 2/10
# 391/391 [==============================] - 7s 19ms/step - loss: 1.1096 - accuracy: 0.6059 - val_loss: 0.9547 - val_accuracy: 0.6699
# Epoch 3/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.9152 - accuracy: 0.6787 - val_loss: 0.8105 - val_accuracy: 0.7148
# Epoch 4/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.8018 - accuracy: 0.7233 - val_loss: 0.7687 - val_accuracy: 0.7338
# Epoch 5/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.7266 - accuracy: 0.7448 - val_loss: 0.7120 - val_accuracy: 0.7530
# Epoch 6/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.6534 - accuracy: 0.7707 - val_loss: 0.6730 - val_accuracy: 0.7694
# Epoch 7/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.5914 - accuracy: 0.7928 - val_loss: 0.6573 - val_accuracy: 0.7742
# Epoch 8/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.5408 - accuracy: 0.8091 - val_loss: 0.6581 - val_accuracy: 0.7758
# Epoch 9/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.4986 - accuracy: 0.8248 - val_loss: 0.6436 - val_accuracy: 0.7812
# Epoch 10/10
# 391/391 [==============================] - 7s 19ms/step - loss: 0.4656 - accuracy: 0.8350 - val_loss: 0.6622 - val_accuracy: 0.7771
